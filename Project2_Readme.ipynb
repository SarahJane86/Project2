# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahJane86/Project2/blob/main/Project2_Readme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heart Failure
# ## This project was to explore how different variables affect a patient with heart failure.
#
# **Author**: Sarah Musselwhite
#
# ### Business problem:
#
# With this project, I am hoping to study the effects of different variables in Heart Failure patients.
#
#
# ### Data:
# * age: Age of the patient
# * anaemia: If the patient had the haemoglobin below the normal range
# * diabetes: If the patient was diabetic
# * high_blood_pressure: If the patient had hypertension
# * sex: The sex of the patient
# * smoking: If the patient smokes actively or ever did in past
# * time: It is the time of the patient's follow-up visit for the disease in months
# * DEATH_EVENT: If the patient deceased during the follow-up period
#
#
# ## Methods
# * Load Data
# * Data Cleaning (missing values, duplicate values, null values)
# * Univariate Exploratory Visuals
# * Identifying any correlations
# * Multivariate Visuals
# * Preprocessing
# * Train, Test, Split
# * Machine Learning
# * Classification Metrics
# * PCA
#
# ## Results
#
#
# #### Age as a contributor to death in heart failure patients.
# ![projectimage1.png](data:image/png;base64,...)
# > For this visualization, I am exploring the trends in this data how differently age affects death events.
#
# #### Age Vs. Hypertension (High Blood Pressure) in Heart Failure Patients
# ![projectimage2.png](data:image/png;base64,...)
# > I wanted to explore if hypertension had any sort of trend or bearing on death events in heart failure patients. Just looking at the visual here, it seems this data varies, quite a bit, theres really no trend. There are other variables at play here and no direct trend.
#
# ## Model
# I chose the random forest model, its accuracy is higher. While the time it takes to run the model is higher, it is only by mere miliseconds.
#
# ## Recommendations:
#
# Possibly explore more variables. I would move to include other factors such as health history, genetic predisposition, and possibly other lifestyle habits( alcohol consumption, exercise, diet, etc.)
#
#
# ## Limitations & Next Steps
#
# Limitations were the data itself, while I did drop certain rows, many of them to the common lay person would make little sense. Also much of the data was nominal. I would love to explore deeper with broader variables.
#
# Next steps would be to possibly regather the data, and re-valuate with the variables I suggested above.
#
#
# ### For further information
#
#
# For any additional questions, please contact **SarahMegan86@gmail.com**
