# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahJane86/Project2/blob/main/README.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heart Failure
# ## This project was to explore how different variables affect a patient with heart failure.
#
# **Author**: Sarah Musselwhite
#
# ### Business problem:
#
# With this project, I am hoping to study the effects of different variables in Heart Failure patients.
#
#
# ### Data:
# * age: Age of the patient
# * anaemia: If the patient had the haemoglobin below the normal range
# * diabetes: If the patient was diabetic
# * high_blood_pressure: If the patient had hypertension
# * sex: The sex of the patient
# * smoking: If the patient smokes actively or ever did in past
# * time: It is the time of the patient's follow-up visit for the disease in months
# * DEATH_EVENT: If the patient deceased during the follow-up period
#
# #### - Dropped columns:( I chose to drop these columns to simplify the dataset. Many of these terms to the common, non medically trained individual, could be difficult to understand.)
#
# * ejection_fraction: Ejection fraction is a measurement of how much blood the left ventricle pumps out with each contraction
# * creatinine_phosphokinase: The level of the creatine phosphokinase in the blood in mcg/L
# * platelets: Platelet count of blood in kiloplatelets/mL
# * serum_creatinine: The level of serum creatinine in the blood in mg/dL
# * serum_sodium: The level of serum sodium in the blood in mEq/L
#
#
#
# ## Methods
# * Load Data
# * Data Cleaning (missing values, duplicate values, null values)
# * Univariate Exploratory Visuals
# * Identifying any correlations
# * Multivariate Visuals
# * Preprocessing
# * Train, Test, Split
# * Machine Learning
# * Classification Metrics
# * PCA
#
# ## Results
#
#
# #### Age as a contributor to death in heart failure patients.
# ![projectimage1.png](data:image/png;base64,...)
# > For this visualization, I am exploring the trends in this data how differently age affects death events.
#
# #### Age vs Smoking in Heart Failure Patients
# !![smoking-ageviz.png](data:image/png;base64,...)
# > I wanted to explore if and possibly how much heart failure patients smoke as they age.
#
# ## Model
# The Logistic Regressor is my model of choice, due to accuracy. Out of all I ran, this one seemed to have higher values in accuracy scores.
#
# ## Recommendations:
# I  made this analysis to promtote general awareness about heart health and factors that one should keep in mind when considering their own heart health.
#
# To explore more of this dataset please check: https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data
#
#
# ## Limitations & Next Steps
# I would move to include other factors such as health history, genetic predisposition, and possibly other lifestyle habits( alcohol consumption, exercise, diet, etc.) Limitations were the data itself, while I did drop certain rows, many of them to the common person(non-medical) would make little sense. Also much of the data was nominal. I would love to explore deeper with broader variables.
#
# Next steps would be to possibly regather the data, and re-valuate with the variables I suggested above.
#
#
# ### For further information
#
#
# For any additional questions regarding my report, please contact **SarahMegan86@gmail.com**
